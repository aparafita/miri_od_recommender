# %%
from domino.utils.jupyter import notebook_init
notebook_init()

# %%
import os.path
import re

from Levenshtein import distance as lev
import pandas as pd
np = pd.np

% matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from multiprocessing import Pool

from rdflib import Graph, URIRef, Literal
from rdflib.namespace import OWL, RDF, XSD

# %%
path = lambda filename, sep='/': os.path.join(*filename.split(sep))

# %%
restaurants = pd.read_csv(path('data/entity_resolution/restaurant.csv'))
transports = pd.read_csv(path('data/entity_resolution/transport.csv'))

# %%
restaurants['source'] = restaurants.restaurant.str.startswith('http://schema.org/resource/eatery_')

# %%
restaurants = restaurants.set_index('restaurant')

# %%
names = list(restaurants.name.str.lower())
coords = list(restaurants[['latitude', 'longitude']].values)
source = list(restaurants.source)

# %%
def compute(n1):
    name1, coords1, src1 = names[n1], coords[n1], source[n1]
    
    results = []
    
    for n2, (name2, coords2, src2) in enumerate(
        zip(names[n1 + 1:], coords[n1 + 1:], source[n1 + 1:])
    ):
        # don't compare two entities of the same source
        if src1 == src2: continue 
            
        n2 += n1 + 1
        
        d_lev = lev(name1, name2) / max(len(name1), len(name2))
        d_euc = ((coords1 - coords2)**2).sum()
        
        results.append((n1, n2, d_lev, d_euc))
    
    return results

# %%
pool = Pool(3)

# %%
n1s = list(
    np.random.choice(
        np.arange(len(names)),
        len(names),
        replace=False
    )
)

# %%
results = pool.map(compute, n1s)

# %%
sum(map(len, results))
# Out:
# 5230827

# %%
dists = pd.concat(list(map(pd.DataFrame, results)))
dists.columns = ['n1', 'n2', 'lev', 'euc']

# %%
dists.shape
# Out:
# (5230827, 4)

# %%
dists.head()
# Out:
#     n1   n2   lev       euc
# 0  493  711  0.88  0.000068
# 1  493  712  0.92  0.000718
# 2  493  713  0.88  0.000854
# 3  493  714  0.82  0.001477
# 4  493  715  0.86  0.000073

# %%
dists.to_csv(os.path.join('tmp_data', 'dists.csv'), index=False)

# %%
dists['n1_name'] = np.array(names)[dists.n1]
dists['n2_name'] = np.array(names)[dists.n2]

# %%
dists = dists.sort_values(['lev', 'euc'])

# %% [markdown]
# If lev = 0, they are the same. The first pair (sorting by euc) is the one assigned.

# %%
dists[dists.lev > 0].head(50)
# Out:
#        n1    n2       lev           euc                      n1_name  \
# 6367  649  7078  0.037037  3.164942e-08  restaurant vegetalia *raval
# 7213   73  7924  0.041667  1.518312e-09      restaurant el paraguayo
# 6774  288  7485  0.041667  1.860292e-09      restaurant tantarantana
# 2157  568  2868  0.043478  1.414656e-08       restaurant bistrot bcn
# 4165  613  4876  0.045455  2.005852e-09        restaurant margherita
# 7138   70  7849  0.045455  1.090557e-04        restaurant pa i trago
# 4920   93  5631  0.047619  5.387999e-10         restaurant biocenter
# 5681  629  6392  0.047619  1.060777e-09         restaurant mano rota
# 6040   87  6751  0.047619  2.739807e-09         restaurant cal boter
# 7114  213  7825  0.047619  3.038132e-09         restaurant silvestre
# 7250    4  7961  0.047619  4.051407e-08        restaurant  bona sort
# 5813  167  6524  0.047619  4.892424e-07         restaurant la bodega
# 7052  164  7763  0.050000  5.990624e-11          restaurant tetuan 9
# 2632  507  3343  0.050000  3.027439e-10         restaurant telefèric
# 6131   94  6842  0.050000  3.335086e-09          restaurant bonanova
# 7021   55  7732  0.050000  1.914751e-07          restaurant el chato
# 6051  284  6762  0.052632  2.147579e-10           restaurant el foro
# 1516  575  2227  0.052632  6.896182e-10          rostisseria menjabé
# 7206   32  7917  0.052632  4.918439e-09           restaurant el puma
# 4969  144  5680  0.052632  2.780971e-08           restaurant govinda
# 2664  691  3375  0.055556  7.044447e-10            restaurant ferran
# 2268   30  2979  0.055556  4.078471e-07            restaurant triton
# 4816  683  5527  0.058824  5.907778e-10             restaurant arume
# 4733  596  5444  0.071429  1.382902e-10               cafè nou kamel
# 6676  267  7387  0.083333  3.809834e-04      restaurant la bona tapa
# 7216  241  7927  0.095238  3.968783e-10         restaurant el cafetí
# 3354  104  4065  0.100000  3.134451e-10                   café godot
# 1842  530  2553  0.100000  3.422731e-10                   bar cañete
# 5477  205  6188  0.100000  6.695816e-04         bar restaurant bliss
# 1433  362  2144  0.100000  1.726900e-03         mandarina restaurant
# 962    98  1673  0.107143  5.338927e-10  restaurant cal pinxo platja
# 2215   35  2926  0.111111  7.918385e-02           restaurant la poma
# 4341   35  5052  0.111111  4.854640e-01           restaurant la poma
# 1807  646  2518  0.117647  4.286614e-04             restaurant tapeo
# 4686  652  5397  0.117647  1.551721e-03            restaurant alvart
# 5506  351  6217  0.117647  4.915856e-03            restaurant medina
# 6823  135  7534  0.125000  4.671347e-04      bar restaurant la llave
# 5692  561  6403  0.125000  6.625313e-04             restaurant bablu
# 3759  608  4470  0.125000  1.585585e-03              restaurant luki
# 281   655   992  0.125000  4.538303e-03              restaurant leka
# 5692  301  6403  0.133333  1.387822e-04               restaurant al.
# 6516  662  7227  0.133333  9.182344e-04              restaurant kiku
# 1994  163  2705  0.133333  1.421265e-03              restaurant agua
# 6878   59  7589  0.133333  3.485123e-03              restaurant juan
# 4211   59  4922  0.133333  5.594976e-03              restaurant juan
# 6750  137  7461  0.136364  1.055680e-04       restaurant barceloneta
# 4038  260  4749  0.136364  1.944909e-03        restaurant casa juaco
# 224   361   935  0.136364  2.602305e-03       bar restaurant  plat's
# 1760  137  2471  0.136364  6.758950e-03       restaurant barceloneta
# 1340  133  2051  0.142857  7.296427e-05         restaurant el portal
#
#                            n2_name
# 6367    restaurant vegetalia raval
# 7213      restaurante el paraguayo
# 6774      restaurante tantarantana
# 2157       restaurante bistrot bcn
# 4165        restaurante margherita
# 7138        restaurante pa i trago
# 4920         restaurante biocenter
# 5681         restaurante mano rota
# 6040         restaurante cal boter
# 7114         restaurante silvestre
# 7250         restaurante bona sort
# 5813         restaurante la bodega
# 7052          restaurante tetuan 9
# 2632          restaurant teleferic
# 6131          restaurante bonanova
# 7021          restaurante el chato
# 6051           restaurante el foro
# 1516           rostisseria menjabe
# 7206           restaurante el puma
# 4969           restaurante govinda
# 2664            restaurante ferran
# 2268            restaurante triton
# 4816             restaurante arume
# 4733                cafe nou kamel
# 6676      restaurant la bona taula
# 7216         restaurante el cafeti
# 3354                    cafe godot
# 1842                    bar canete
# 5477          bar restaurant elias
# 1433           andurina restaurant
# 962   restaurante cal pinxo paltja
# 2215            restaurant la mama
# 4341            restaurant la pala
# 1807             restaurant etapes
# 4686             restaurante alvar
# 5506              restaurant sedna
# 6823      bar restaurante la llama
# 5692               restaurant bali
# 3759              restaurante luri
# 281               restaurante leku
# 5692               restaurant bali
# 6516               restaurant noku
# 1994                restaurant gut
# 6878               restaurant mian
# 4211               restaurant zian
# 6750        restaurante barcelonia
# 4038        restaurante casa julio
# 224         bar restaurante blau's
# 1760         restaurant barcelonas
# 1340         restaurante el gordal

# %% [markdown]
# lev = 0.1 is the first threshold in which they're not the same

# %%
same_as = {
    (row['n1'], row['n2'])
    for _, row in dists[dists.lev <= 0.1].iterrows()
}

# %%
paired = {x for x, _ in same_as}.union({y for _, y in same_as})

# %%
dists = dists[~(dists.n1.isin(paired) | dists.n2.isin(paired))]

# %%
# Now let's try sorting the other way around
dists.sort_values(['euc', 'lev']).head(20)

# except for some few pairs, there's no more coincidences
# let's leave it like that
# Out:
#        n1    n2       lev           euc  \
# 5909  197  6620  0.760000  8.250224e-12
# 1477  635  2188  0.823529  1.068346e-11
# 7265  277  7976  0.529412  1.537408e-11
# 7265  246  7976  0.581395  1.537408e-11
# 181   277   892  0.764706  1.537408e-11
# 181   246   892  0.813953  1.537408e-11
# 997   246  1708  0.860465  1.537408e-11
# 997   277  1708  0.882353  1.537408e-11
# 2348  222  3059  0.625000  1.830136e-11
# 2764   71  3475  0.891304  2.281790e-11
# 6233   71  6944  0.956522  2.281790e-11
# 1625  541  2336  0.823529  2.441874e-11
# 423   421  1134  0.343750  2.751855e-11
# 3582  687  4293  0.354839  2.913938e-11
# 2375   41  3086  0.842105  3.095756e-11
# 6299   15  7010  0.523810  3.212825e-11
# 2913  612  3624  0.705882  3.289216e-11
# 1905   39  2616  0.793103  4.092188e-11
# 926   135  1637  0.652174  4.139086e-11
# 2666  302  3377  0.727273  4.229816e-11
#
#                                              n1_name                   n2_name
# 5909                       restaurant reina selecció               tap de suro
# 1477                               restaurant zeruko                 crudo bar
# 7265              restaurant el rebujito de moncho's  restaurante al austriaco
# 7265     restaurant barnabier-la cerveseria del port  restaurante al austriaco
# 181               restaurant el rebujito de moncho's       mexican steak house
# 181      restaurant barnabier-la cerveseria del port       mexican steak house
# 997      restaurant barnabier-la cerveseria del port                    talaia
# 997               restaurant el rebujito de moncho's                    talaia
# 2348                        bar restaurant horiginal                 horiginal
# 2764  restaurant mesón morriña - marisqueria gallega                peix fresc
# 6233  restaurant mesón morriña - marisqueria gallega                      wino
# 1625                               restaurant ornina                piscolabis
# 423                 restaurant patagonia beef & wine     patagonia beef & wine
# 3582                 restaurant surf house barcelona      surf house barcelona
# 2375                             restaurant tragaluz               elj apo nes
# 6299                           restaurant txalaparta                txalaparta
# 2913              hotel mercer barcelona - hb-004504         mercer restaurant
# 1905                   restaurant marisqueria marisk                    marisk
# 926                          bar restaurant la llave                  la llave
# 2666                          restaurant freud b'art        tarantino pizzeria

# %%
len(same_as)
# Out:
# 55

# %%
str(OWL)
# Out:
# 'http://www.w3.org/2002/07/owl#'

# %%
graph = Graph()

graph.bind('owl', str(OWL))
graph.bind('', 'http://schema.org/resource/')
graph.bind('ont', 'http://schema.org/ontology/')

for x, y in same_as:
    x = restaurants.index[x]
    y = restaurants.index[y]
    
    graph.add((URIRef(x), OWL.sameAs, URIRef(y)))

# %%
graph.serialize(os.path.join('mapped_sources', 'restaurant_er.ttl'), format='turtle')
